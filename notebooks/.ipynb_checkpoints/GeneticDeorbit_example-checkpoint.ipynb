# %%
using GeneticDeorbit
# Out:
# ┌ Info: Precompiling GeneticDeorbit [79b0f302-fa61-4c36-ac94-ed7326b49fa9]
# └ @ Base loading.jl:1342

# %%
@time begin
    switching_alt = 350e3
    burn_duration = 45*pi/180
    sc = spacecraft(switching_alt, burn_duration)
    my_traj = eval_fitness(sc)
end
@show my_traj.fitness
plotCOES(my_traj)
# Out:
#  73.261243 seconds (416.62 M allocations: 18.649 GiB, 10.65% gc time, 7.16% compilation time)
# my_traj.fitness = 1.297388e6

# %%
@time begin
    switching_alt = 425e3
    burn_duration = 60*pi/180
    sc2 = spacecraft(switching_alt, burn_duration)
    my_traj2 = eval_fitness(sc2)
end
@show my_traj2.fitness - my_traj.fitness
plotCOES(my_traj2)
# Out:
#  67.981689 seconds (407.42 M allocations: 18.147 GiB, 10.00% gc time)
# my_traj2.fitness - my_traj.fitness = -64010.0

# %%
@time begin
    switching_alt = 200e3
    burn_duration = 0*pi/180
    sc3 = spacecraft(switching_alt, burn_duration)
    my_traj3 = eval_fitness(sc3)
end
@show my_traj3.fitness - my_traj.fitness
plotCOES(my_traj3)
# Out:
#  49.734751 seconds (407.42 M allocations: 18.147 GiB, 6.38% gc time)
# my_traj3.fitness - my_traj.fitness = 4067.5
